# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import re
import math
import spacy
import json
import os
from pathlib import Path

# %%
class SmartSearchEngine:
    def __init__(self, df=None, json_folder=None, load_from_file=None):
        """
        Initialize the search engine with either:
        - df: A pandas DataFrame (original behavior)
        - json_folder: Path to folder containing JSON files
        - load_from_file: Path to pre-built index
        """
        # Load data from JSON folder if provided
        if json_folder is not None:
            print(f"Loading JSON files from: {json_folder}")
            self.df = self.load_json_files(json_folder)
        elif df is not None:
            self.df = df
        else:
            raise ValueError("Must provide either df or json_folder")
        
        self.N = len(self.df)
        
        # Load spaCy model
        print("Loading spaCy model...")
        self.nlp = spacy.load("en_core_web_sm")
        
        # Define fields to index
        self.fields = ['Title', 'Director', 'Genres', 'Overview', 'Release_Date']
        
        if load_from_file:
            # Load index from file
            self.load_index(load_from_file)
        else:
            # Build index from scratch
            self.inverted_index = defaultdict(lambda: defaultdict(list))
            self.doc_lengths = {}
            self.avg_doc_length = {}
            self.directors_set = set()
            self.genres_set = set()
            self.title_words = set()
            self.years_set = set()
            
            self.build_index()
            self.build_recognition_dicts()
    
    @staticmethod
    def load_json_files(folder_path):
        """
        Load all JSON files from a folder and combine into a DataFrame.
        Each JSON file should contain one movie record.
        """
        folder = Path(folder_path)
        
        if not folder.exists():
            raise FileNotFoundError(f"Folder not found: {folder_path}")
        
        # Get all JSON files
        json_files = list(folder.glob("*.json"))
        
        if not json_files:
            raise ValueError(f"No JSON files found in: {folder_path}")
        
        print(f"Found {len(json_files)} JSON files")
        
        # Load all JSON files
        movies = []
        for json_file in json_files:
            try:
                with open(json_file, 'r', encoding='utf-8') as f:
                    movie_data = json.load(f)
                    movies.append(movie_data)
            except Exception as e:
                print(f"Warning: Could not load {json_file.name}: {e}")
        
        print(f"Successfully loaded {len(movies)} movies")
        
        # Convert to DataFrame
        df = pd.DataFrame(movies)
        
        # Ensure required columns exist
        required_columns = ['Title', 'Director', 'Genres', 'Overview', 'Release_Date']
        missing_columns = [col for col in required_columns if col not in df.columns]
        
        if missing_columns:
            print(f"Warning: Missing columns: {missing_columns}")
            for col in missing_columns:
                df[col] = None
        
        return df
    
    def preprocess_text(self, text, is_date=False):
        """Clean and tokenize with spaCy + lemmatization"""
        if pd.isna(text):
            return []
        text = str(text).lower()
        
        # For dates, extract year (format: YYYY-MM-DD or just YYYY)
        if is_date:
            year_match = re.findall(r'\b(?:19|20)\d{2}\b', text)
            return year_match if year_match else []
        
        # Process with spaCy
        doc = self.nlp(text)
        
        # Extract lemmas with spaCy's built-in stopwords
        tokens = [
            token.lemma_ 
            for token in doc 
            if not token.is_stop          # spaCy's built-in stopwords
            and not token.is_punct        # Remove punctuation
            and not token.is_space        # Remove whitespace
            and len(token.lemma_) > 2     # Remove short tokens
            and token.is_alpha            # Keep only alphabetic tokens
        ]
        
        return tokens
    
    def build_index(self):
        """Build inverted index by field"""
        print("Building inverted index...")
        
        for field in self.fields:
            self.doc_lengths[field] = {}
            self.avg_doc_length[field] = 0
        
        for idx, row in self.df.iterrows():
            for field in self.fields:
                # Special treatment for dates
                is_date_field = (field == 'Release_Date')
                tokens = self.preprocess_text(row[field], is_date=is_date_field)
                self.doc_lengths[field][idx] = len(tokens)
                
                term_freq = defaultdict(int)
                for token in tokens:
                    term_freq[token] += 1
                
                for term, freq in term_freq.items():
                    self.inverted_index[field][term].append((idx, freq))
        
        for field in self.fields:
            if self.doc_lengths[field]:
                self.avg_doc_length[field] = np.mean(list(self.doc_lengths[field].values()))
        
        print(f"Index built: {len(self.df)} documents indexed")
    
    def build_recognition_dicts(self):
        """Build dictionaries to automatically recognize terms"""
        print("Building recognition dictionaries...")
        
        # Extract all directors
        for director in self.df['Director'].dropna().unique():
            tokens = self.preprocess_text(director)
            self.directors_set.update(tokens)
        
        # Extract all genres
        for genres in self.df['Genres'].dropna():
            for genre in str(genres).split(','):
                tokens = self.preprocess_text(genre.strip())
                self.genres_set.update(tokens)
        
        # Extract important words from titles
        for title in self.df['Title'].dropna():
            tokens = self.preprocess_text(title)
            self.title_words.update(tokens)
        
        # Extract all years from release dates
        for date in self.df['Release_Date'].dropna():
            years = self.preprocess_text(date, is_date=True)
            self.years_set.update(years)
        
        print(f"Unique directors: {len(self.directors_set)}")
        print(f"Unique genres: {len(self.genres_set)}")
        print(f"Available years: {len(self.years_set)}")
    
    def classify_query_terms(self, query_tokens):
        """Automatically classify each query term"""
        classified = {
            'director': [],
            'genre': [],
            'title': [],
            'year': [],
            'general': []
        }
        
        for term in query_tokens:
            # Check if it's a year (4 digits starting with 19 or 20)
            if re.match(r'^(?:19|20)\d{2}$', term):
                classified['year'].append(term)
            # Check in which field the term appears most
            elif term in self.directors_set:
                classified['director'].append(term)
            elif term in self.genres_set:
                classified['genre'].append(term)
            elif term in self.title_words:
                classified['title'].append(term)
            else:
                # General term, search everywhere
                classified['general'].append(term)
        
        return classified
    
    def bm25_score(self, term, doc_id, field, k1=1.5, b=0.75):
        """Calculate BM25 score for a term in a document"""
        if term not in self.inverted_index[field]:
            return 0.0
        
        tf = 0
        for doc, freq in self.inverted_index[field][term]:
            if doc == doc_id:
                tf = freq
                break
        
        if tf == 0:
            return 0.0
        
        df = len(self.inverted_index[field][term])
        idf = math.log((self.N - df + 0.5) / (df + 0.5) + 1.0)
        
        doc_len = self.doc_lengths[field].get(doc_id, 0)
        avg_len = self.avg_doc_length[field]
        
        if avg_len == 0:
            return 0.0
        
        norm = 1 - b + b * (doc_len / avg_len)
        score = idf * (tf * (k1 + 1)) / (tf + k1 * norm)
        
        return score
    
    def search(self, query, top_n=10):
        """Smart search with automatic term classification"""
        # Extract years BEFORE preprocessing
        years_in_query = re.findall(r'\b(?:19|20)\d{2}\b', query)
        
        # Tokenize query with spaCy + lemmatization
        query_tokens = self.preprocess_text(query)
        
        # Add extracted years to tokens
        query_tokens.extend(years_in_query)
        
        if not query_tokens:
            return pd.DataFrame()
        
        # Classify query terms
        classified = self.classify_query_terms(query_tokens)
        
        # Debug: display classification
        print(f"\n=== Term Classification ===")
        for category, terms in classified.items():
            if terms:
                print(f"{category.capitalize()}: {terms}")
        
        # Collect all candidate documents
        candidate_docs = set()
        
        # Search terms in their corresponding fields
        field_mapping = {
            'director': ['Director'],
            'genre': ['Genres'],
            'title': ['Title'],
            'year': ['Release_Date'],
            'general': ['Title', 'Director', 'Genres', 'Overview']
        }
        
        for category, terms in classified.items():
            target_fields = field_mapping[category]
            for term in terms:
                for field in target_fields:
                    if term in self.inverted_index[field]:
                        for doc_id, _ in self.inverted_index[field][term]:
                            candidate_docs.add(doc_id)
        
        # Calculate scores for each document
        scores = {}
        for doc_id in candidate_docs:
            total_score = 0.0
            
            # Score for director terms
            for term in classified['director']:
                score = self.bm25_score(term, doc_id, 'Director')
                total_score += score * 1.0
            
            # Score for genre terms
            for term in classified['genre']:
                score = self.bm25_score(term, doc_id, 'Genres')
                total_score += score * 1.0
            
            # Score for title terms
            for term in classified['title']:
                score = self.bm25_score(term, doc_id, 'Title')
                total_score += score * 1.0
            
            # Score for years
            for term in classified['year']:
                score = self.bm25_score(term, doc_id, 'Release_Date')
                total_score += score * 1.0
            
            # Score for general terms
            for term in classified['general']:
                for field in ['Title', 'Director', 'Genres', 'Overview', 'Release_Date']:
                    score = self.bm25_score(term, doc_id, field)
                    total_score += score * 1.0
            
            scores[doc_id] = total_score
        
        # Sort by descending score
        sorted_docs = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:top_n]
        
        if not sorted_docs:
            return pd.DataFrame()
        
        result_indices = [doc_id for doc_id, _ in sorted_docs]
        result_scores = [score for _, score in sorted_docs]
        
        results = self.df.loc[result_indices, ['Title', 'Overview', 'Genres', 'Director', 'Release_Date']].copy()
        results['score'] = result_scores
        
        return results.reset_index(drop=True)
    
    def save_index(self, folder_path="../data/index_data"):
        """Save inverted index and metadata to JSON"""
        os.makedirs(folder_path, exist_ok=True)
        
        print(f"\nSaving index to '{folder_path}'...")
        
        # Convert inverted_index to serializable format
        serializable_index = {}
        for field, terms_dict in self.inverted_index.items():
            serializable_index[field] = {}
            for term, postings in terms_dict.items():
                serializable_index[field][term] = [[int(doc_id), int(freq)] for doc_id, freq in postings]
        
        # Save inverted index
        index_path = os.path.join(folder_path, "inverted_index.json")
        with open(index_path, 'w', encoding='utf-8') as f:
            json.dump(serializable_index, f, ensure_ascii=False, indent=2)
        
        # Save metadata
        metadata = {
            'N': self.N,
            'doc_lengths': {field: {int(k): v for k, v in lengths.items()} 
                           for field, lengths in self.doc_lengths.items()},
            'avg_doc_length': self.avg_doc_length,
            'directors_set': list(self.directors_set),
            'genres_set': list(self.genres_set),
            'title_words': list(self.title_words),
            'years_set': list(self.years_set),
            'fields': self.fields
        }
        
        metadata_path = os.path.join(folder_path, "metadata.json")
        with open(metadata_path, 'w', encoding='utf-8') as f:
            json.dump(metadata, f, ensure_ascii=False, indent=2)
        
        # Display stats
        index_size = os.path.getsize(index_path) / 1024
        metadata_size = os.path.getsize(metadata_path) / 1024
        
        print(f"✓ Index saved successfully!")
        print(f"  📁 Folder: {folder_path}")
        print(f"  📄 inverted_index.json: {index_size:.2f} KB")
        print(f"  📄 metadata.json: {metadata_size:.2f} KB")
        print(f"  📊 Total: {index_size + metadata_size:.2f} KB")
    
    def load_index(self, folder_path="../data"):
        """Load inverted index from JSON"""
        print(f"\nLoading index from '{folder_path}'...")
        
        index_path = os.path.join(folder_path, "inverted_index.json")
        metadata_path = os.path.join(folder_path, "metadata.json")
        
        if not os.path.exists(index_path):
            raise FileNotFoundError(f"File not found: {index_path}")
        if not os.path.exists(metadata_path):
            raise FileNotFoundError(f"File not found: {metadata_path}")
        
        # Load inverted index
        with open(index_path, 'r', encoding='utf-8') as f:
            serializable_index = json.load(f)
        
        # Rebuild defaultdict structure with tuples
        self.inverted_index = defaultdict(lambda: defaultdict(list))
        for field, terms_dict in serializable_index.items():
            for term, postings in terms_dict.items():
                self.inverted_index[field][term] = [(doc_id, freq) for doc_id, freq in postings]
        
        # Load metadata
        with open(metadata_path, 'r', encoding='utf-8') as f:
            metadata = json.load(f)
        
        self.N = metadata['N']
        self.doc_lengths = {field: {int(k): v for k, v in lengths.items()} 
                           for field, lengths in metadata['doc_lengths'].items()}
        self.avg_doc_length = metadata['avg_doc_length']
        self.directors_set = set(metadata['directors_set'])
        self.genres_set = set(metadata['genres_set'])
        self.title_words = set(metadata['title_words'])
        self.years_set = set(metadata['years_set'])
        self.fields = metadata['fields']
        
        print(f"✓ Index loaded successfully!")

# %%
# ============ USAGE EXAMPLES ============

# Example 1: Load from JSON folder
print("=" * 60)
print("EXAMPLE 1: Creating search engine from JSON folder")
print("=" * 60)
engine = SmartSearchEngine(json_folder="../../data/Docs")
engine.save_index("../../data/index_data")
# Out:
# ============================================================
# EXAMPLE 1: Creating search engine from JSON folder
# ============================================================
# Loading JSON files from: ../../data/Docs
# Found 3500 JSON files
# Successfully loaded 3500 movies
# Loading spaCy model...
# Building inverted index...
# Index built: 3500 documents indexed
# Building recognition dictionaries...
# Unique directors: 1905
# Unique genres: 20
# Available years: 83
#
# Saving index to '../../data/index_data'...
# ✓ Index saved successfully!
#   📁 Folder: ../../data/index_data
#   📄 inverted_index.json: 4788.94 KB
#   📄 metadata.json: 359.57 KB
#   📊 Total: 5148.51 KB

# %%
# Example 2: Search
print("\n" + "=" * 60)
print("EXAMPLE 2: Searching")
print("=" * 60)
results = engine.search("action movies of christopher nolan 2010", top_n=10)
print(results[['Title', 'Director', 'Genres', 'Release_Date', 'score']])
# Out:
# ============================================================
# EXAMPLE 2: Searching
# ============================================================
#
# === Term Classification ===
# Director: ['christopher', 'nolan']
# Genre: ['action', 'movie']
# Year: ['2010']
#                                 Title               Director  \
# 0                           Inception      Christopher Nolan
# 1                       Batman Begins      Christopher Nolan
# 2                     The Dark Knight      Christopher Nolan
# 3               The Dark Knight Rises      Christopher Nolan
# 4                            Insomnia      Christopher Nolan
# 5                        Interstellar      Christopher Nolan
# 6                             Memento      Christopher Nolan
# 7                        The Prestige      Christopher Nolan
# 8  Mission: Impossible - Rogue Nation  Christopher McQuarrie
# 9                  The Way of the Gun  Christopher McQuarrie
#
#                                Genres Release_Date      score
# 0  Action, Science Fiction, Adventure   2010-07-15  15.415056
# 1                Action, Crime, Drama   2005-06-10  12.569445
# 2      Drama, Action, Crime, Thriller   2008-07-16  12.398835
# 3      Action, Crime, Drama, Thriller   2012-07-17  12.398835
# 4                     Thriller, Crime   2002-05-24  11.300340
# 5   Adventure, Drama, Science Fiction   2014-11-05  11.300340
# 6                   Mystery, Thriller   2000-10-11  11.300340
# 7     Drama, Mystery, Science Fiction   2006-10-19  11.300340
# 8                   Action, Adventure   2015-07-23   6.734147
# 9      Action, Crime, Drama, Thriller   2000-09-08   6.330187

# %%
# Example 3: Load from pre-built index (faster for repeated use)
print("\n" + "=" * 60)
print("EXAMPLE 3: Loading from pre-built index")
print("=" * 60)
# Note: You need to pass the DataFrame when loading from index
df = SmartSearchEngine.load_json_files("../../data/Docs")
engine_fast = SmartSearchEngine(df=df, load_from_file="../../data/index_data")

# Example 4: More search queries
print("\n" + "=" * 60)
print("EXAMPLE 4: More searches")
print("=" * 60)
queries = [
    "science fiction 2014",
    "spielberg movies",
    "comedy romance"
]

for query in queries:
    print(f"\nQuery: '{query}'")
    results = engine.search(query, top_n=5)
    print(results[['Title', 'Director', 'Release_Date', 'score']])
# Out:
# ============================================================
# EXAMPLE 3: Loading from pre-built index
# ============================================================
# Found 3500 JSON files
# Successfully loaded 3500 movies
# Loading spaCy model...
#
# Loading index from '../../data/index_data'...
# ✓ Index loaded successfully!
#
# ============================================================
# EXAMPLE 4: More searches
# ============================================================
#
# Query: 'science fiction 2014'
#
# === Term Classification ===
# Genre: ['science', 'fiction']
# Year: ['2014']
#               Title        Director Release_Date     score
# 0          Automata     Gabe Ibáñez   2014-10-09  7.013517
# 1        The Signal  William Eubank   2014-03-15  7.013517
# 2         The Giver   Phillip Noyce   2014-08-13  7.013517
# 3              Lucy      Luc Besson   2014-07-25  7.013517
# 4  Edge of Tomorrow      Doug Liman   2014-05-27  7.013517
#
# Query: 'spielberg movies'
#
# === Term Classification ===
# Director: ['spielberg']
# Genre: ['movie']
#                         Title          Director Release_Date     score
# 0   A Charlie Brown Christmas     Bill Melendez   1965-12-09  5.594881
# 1  Stargate: The Ark of Truth  Robert C. Cooper   2008-03-11  4.931873
# 2         Catch Me If You Can  Steven Spielberg   2002-12-16  4.885185
# 3             Bridge of Spies  Steven Spielberg   2015-10-15  4.885185
# 4                   War Horse  Steven Spielberg   2011-12-25  4.885185
#
# Query: 'comedy romance'
#
# === Term Classification ===
# Genre: ['comedy', 'romance']
#                   Title      Director Release_Date     score
# 0        American Pie 2   J.B. Rogers   2001-08-10  3.143193
# 1      About Last Night    Steve Pink   2014-02-14  3.143193
# 2  Under the Tuscan Sun  Audrey Wells   2003-09-20  3.143193
# 3      Meet the Parents     Jay Roach   2000-10-06  3.143193
# 4              Mallrats   Kevin Smith   1995-10-20  3.143193

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import ndcg_score


class SearchEngineEvaluator:
    """
    Advanced search engine evaluation with graded relevance
    """
    
    def __init__(self, search_engine, df):
        self.engine = search_engine
        self.df = df
    
    def calculate_relevance_score(self, result, query_info):
        """
        Calculate relevance score (0-3) for a result given a query
        
        0 = Not relevant
        1 = Partially relevant (matches 1 criterion)
        2 = Relevant (matches 2 criteria)
        3 = Highly relevant (matches all criteria)
        """
        score = 0
        matches = []
        
        # Check director match
        if 'director' in query_info:
            result_director = str(result.get('Director', '')).lower()
            query_director = query_info['director'].lower()
            if query_director in result_director:
                score += 1
                matches.append('director')
        
        # Check genre match
        if 'genre' in query_info:
            result_genres = str(result.get('Genres', '')).lower()
            query_genre = query_info['genre'].lower()
            if query_genre in result_genres:
                score += 1
                matches.append('genre')
        
        # Check year match
        if 'year' in query_info:
            result_date = str(result.get('Release_Date', ''))
            query_year = str(query_info['year'])
            if query_year in result_date:
                score += 1
                matches.append('year')
        
        # Check title match
        if 'title' in query_info:
            result_title = str(result.get('Title', '')).lower()
            query_title = query_info['title'].lower()
            if query_title in result_title:
                score += 1
                matches.append('title')
        
        return score, matches
    
    def evaluate_single_query(self, query, criteria, top_n=10, verbose=False):
        """
        Evaluate a single query with detailed breakdown
        
        Args:
            query: Search query string
            criteria: Dict with 'director', 'genre', 'year', 'title' keys
            top_n: Number of results to retrieve
            verbose: If True, print debug info
        
        Returns:
            dict with metrics and detailed results
        """
        # Temporarily disable print statements in search
        import sys
        import io
        
        if not verbose:
            old_stdout = sys.stdout
            sys.stdout = io.StringIO()
        
        try:
            results = self.engine.search(query, top_n=top_n)
        finally:
            if not verbose:
                sys.stdout = old_stdout
        
        if results.empty:
            return {
                'query': query,
                'precision_at_k': 0.0,
                'mrr': 0.0,
                'ndcg': 0.0,
                'results': []
            }
        
        # Calculate relevance for each result
        relevance_scores = []
        detailed_results = []
        
        for idx, row in results.iterrows():
            result_dict = row.to_dict()
            rel_score, matches = self.calculate_relevance_score(result_dict, criteria)
            relevance_scores.append(rel_score)
            
            detailed_results.append({
                'title': result_dict['Title'],
                'director': result_dict.get('Director', 'N/A'),
                'genres': result_dict.get('Genres', 'N/A'),
                'year': result_dict.get('Release_Date', 'N/A')[:4] if result_dict.get('Release_Date') else 'N/A',
                'search_score': result_dict['score'],
                'relevance': rel_score,
                'matches': matches
            })
        
        # Calculate metrics
        num_criteria = len([k for k in ['director', 'genre', 'year', 'title'] if k in criteria])
        
        # Precision@K (consider relevant if matches at least 1 criterion)
        relevant_count = sum(1 for score in relevance_scores if score > 0)
        precision_at_k = relevant_count / len(relevance_scores)
        
        # Mean Reciprocal Rank (position of first highly relevant result)
        mrr = 0.0
        for i, score in enumerate(relevance_scores, 1):
            if score == num_criteria:  # Fully matches all criteria
                mrr = 1.0 / i
                break
        
        # NDCG (Normalized Discounted Cumulative Gain)
        if len(relevance_scores) > 0:
            # Reshape for sklearn
            y_true = np.array([relevance_scores])
            y_score = np.array([relevance_scores])
            ndcg = ndcg_score(y_true, y_score)
        else:
            ndcg = 0.0
        
        return {
            'query': query,
            'criteria': criteria,
            'precision_at_k': precision_at_k,
            'mrr': mrr,
            'ndcg': ndcg,
            'results': detailed_results,
            'avg_relevance': np.mean(relevance_scores),
            'perfect_matches': sum(1 for s in relevance_scores if s == num_criteria)
        }
    
    def evaluate_queries(self, test_queries, verbose=False):
        """
        Evaluate multiple queries
        
        Args:
            test_queries: List of dicts with 'query' and criteria keys
            verbose: If True, show search debug info
        
        Returns:
            dict with aggregate metrics
        """
        all_results = []
        
        for test_query in test_queries:
            query = test_query['query']
            criteria = {k: v for k, v in test_query.items() if k != 'query'}
            
            result = self.evaluate_single_query(query, criteria, top_n=10, verbose=verbose)
            all_results.append(result)
        
        # Aggregate metrics
        avg_precision = np.mean([r['precision_at_k'] for r in all_results])
        avg_mrr = np.mean([r['mrr'] for r in all_results])
        avg_ndcg = np.mean([r['ndcg'] for r in all_results])
        avg_relevance = np.mean([r['avg_relevance'] for r in all_results])
        
        return {
            'average_precision@10': avg_precision,
            'mean_reciprocal_rank': avg_mrr,
            'average_ndcg': avg_ndcg,
            'average_relevance': avg_relevance,
            'query_results': all_results
        }
    
    def print_detailed_results(self, evaluation_results, show_per_query=True):
        """
        Pretty print evaluation results
        
        Args:
            evaluation_results: Results from evaluate_queries()
            show_per_query: If True, show detailed per-query breakdown
        """
        # Per-query breakdown - shown first if enabled
        if show_per_query:
            for i, query_result in enumerate(evaluation_results['query_results'], 1):
                print(f"\n{'='*80}")
                print(f"Query #{i}: '{query_result['query']}'")
                print(f"Criteria: {query_result['criteria']}")
                print(f"{'='*80}")
                print(f"Precision@10: {query_result['precision_at_k']*100:.1f}% | "
                      f"MRR: {query_result['mrr']:.3f} | "
                      f"NDCG: {query_result['ndcg']:.3f} | "
                      f"Avg Relevance: {query_result['avg_relevance']:.2f}/3.0")
                
                print(f"\nTop 10 Results:")
                print(f"{'Rank':<5} {'Relevance':<10} {'Matches':<25} {'Title':<40}")
                print(f"{'-'*80}")
                
                for rank, result in enumerate(query_result['results'], 1):
                    relevance_str = f"{result['relevance']}/3 ★"
                    matches_str = ', '.join(result['matches']) if result['matches'] else 'none'
                    title_short = result['title'][:37] + "..." if len(result['title']) > 40 else result['title']
                    
                    print(f"{rank:<5} {relevance_str:<10} {matches_str:<25} {title_short:<40}")
        
        # Overall metrics - always shown at the bottom
        print("\n" + "="*80)
        print("SEARCH ENGINE EVALUATION - DETAILED RESULTS")
        print("="*80)
        
        print(f"\n{'-'*80}")
        print(f"{'OVERALL METRICS':^80}")
        print(f"{'-'*80}")
        print(f"Average Precision@10: {evaluation_results['average_precision@10']*100:.2f}%")
        print(f"Mean Reciprocal Rank: {evaluation_results['mean_reciprocal_rank']:.4f}")
        print(f"Average NDCG:         {evaluation_results['average_ndcg']:.4f}")
        print(f"Average Relevance:    {evaluation_results['average_relevance']:.2f}/3.0")
        print(f"\nTotal Queries Evaluated: {len(evaluation_results['query_results'])}")
        
        # Interpretation
        precision = evaluation_results['average_precision@10']
        if precision >= 0.9:
            rating = "EXCELLENT ★★★★★"
        elif precision >= 0.8:
            rating = "VERY GOOD ★★★★"
        elif precision >= 0.7:
            rating = "GOOD ★★★"
        elif precision >= 0.6:
            rating = "FAIR ★★"
        else:
            rating = "NEEDS IMPROVEMENT ★"
        
        print(f"\nOverall Rating: {rating}")
        print("="*80)


# ============ HELPER FUNCTIONS ============

def create_test_query(query, director=None, genre=None, year=None, title=None):
    """Helper to create test query with criteria"""
    test = {'query': query}
    if director:
        test['director'] = director
    if genre:
        test['genre'] = genre
    if year:
        test['year'] = year
    if title:
        test['title'] = title
    return test


# ============ USAGE EXAMPLE ============

# Load your search engine
# engine = SmartSearchEngine(json_folder="../data/movies_json")
# df = engine.df

# Create test queries
test_queries = [
    create_test_query(
        query="action movies of christopher nolan 2010",
        director="Christopher Nolan",
        genre="Action",
        year=2010
    ),
    create_test_query(
        query="spielberg adventure",
        director="Spielberg",
        genre="Adventure"
    ),
    create_test_query(
        query="horror 2019",
        genre="Horror",
        year=2019
    ),
    create_test_query(
        query="woody allen comedy",
        director="Woody Allen",
        genre="Comedy"
    ),
    create_test_query(
        query="scorsese crime drama",
        director="Scorsese",
        genre="Crime"
    ),
    create_test_query(
        query="batman dark knight",
        title="Batman"
    ),
    create_test_query(
        query="pixar animation",
        genre="Animation"
    ),
    create_test_query(
        query="tarantino 1994",
        director="Tarantino",
        year=1994
    ),
]

# Evaluate (verbose=False hides the === Term Classification === messages)
evaluator = SearchEngineEvaluator(engine, df)
results = evaluator.evaluate_queries(test_queries, verbose=False)

# Print results
evaluator.print_detailed_results(results, show_per_query=True)
# Out:
# ================================================================================
# Query #1: 'action movies of christopher nolan 2010'
# Criteria: {'director': 'Christopher Nolan', 'genre': 'Action', 'year': 2010}
# ================================================================================
# Precision@10: 100.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 1.50/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     3/3 ★      director, genre, year     Inception
# 2     2/3 ★      director, genre           Batman Begins
# 3     2/3 ★      director, genre           The Dark Knight
# 4     2/3 ★      director, genre           The Dark Knight Rises
# 5     1/3 ★      director                  Insomnia
# 6     1/3 ★      director                  Interstellar
# 7     1/3 ★      director                  Memento
# 8     1/3 ★      director                  The Prestige
# 9     1/3 ★      genre                     Mission: Impossible - Rogue Nation
# 10    1/3 ★      genre                     The Way of the Gun
#
# ================================================================================
# Query #2: 'spielberg adventure'
# Criteria: {'director': 'Spielberg', 'genre': 'Adventure'}
# ================================================================================
# Precision@10: 100.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 2.00/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     2/3 ★      director, genre           Indiana Jones and the Temple of Doom
# 2     2/3 ★      director, genre           Raiders of the Lost Ark
# 3     2/3 ★      director, genre           Indiana Jones and the Last Crusade
# 4     2/3 ★      director, genre           Indiana Jones and the Kingdom of the ...
# 5     2/3 ★      director, genre           The Adventures of Tintin
# 6     2/3 ★      director, genre           Jurassic Park
# 7     2/3 ★      director, genre           The BFG
# 8     2/3 ★      director, genre           Jaws
# 9     2/3 ★      director, genre           A.I. Artificial Intelligence
# 10    2/3 ★      director, genre           The Lost World: Jurassic Park
#
# ================================================================================
# Query #3: 'horror 2019'
# Criteria: {'genre': 'Horror', 'year': 2019}
# ================================================================================
# Precision@10: 100.0% | MRR: 0.000 | NDCG: 1.000 | Avg Relevance: 1.00/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     1/3 ★      genre                     Cabin Fever
# 2     1/3 ★      genre                     Two Evil Eyes
# 3     1/3 ★      genre                     Friday the 13th Part III
# 4     1/3 ★      genre                     The Veil
# 5     1/3 ★      genre                     Friday the 13th Part VIII: Jason Take...
# 6     1/3 ★      genre                     Friday the 13th Part 2
# 7     1/3 ★      genre                     Child's Play
# 8     1/3 ★      genre                     Ouija
# 9     1/3 ★      genre                     Devil's Due
# 10    1/3 ★      genre                     Paranormal Activity 4
#
# ================================================================================
# Query #4: 'woody allen comedy'
# Criteria: {'director': 'Woody Allen', 'genre': 'Comedy'}
# ================================================================================
# Precision@10: 100.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 2.00/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     2/3 ★      director, genre           Bananas
# 2     2/3 ★      director, genre           Hollywood Ending
# 3     2/3 ★      director, genre           Everything You Always Wanted to Know ...
# 4     2/3 ★      director, genre           Small Time Crooks
# 5     2/3 ★      director, genre           Whatever Works
# 6     2/3 ★      director, genre           Bullets Over Broadway
# 7     2/3 ★      director, genre           Radio Days
# 8     2/3 ★      director, genre           Celebrity
# 9     2/3 ★      director, genre           Everyone Says I Love You
# 10    2/3 ★      director, genre           Scoop
#
# ================================================================================
# Query #5: 'scorsese crime drama'
# Criteria: {'director': 'Scorsese', 'genre': 'Crime'}
# ================================================================================
# Precision@10: 100.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 1.70/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     2/3 ★      director, genre           GoodFellas
# 2     2/3 ★      director, genre           Mean Streets
# 3     2/3 ★      director, genre           Casino
# 4     2/3 ★      director, genre           Taxi Driver
# 5     2/3 ★      director, genre           The Wolf of Wall Street
# 6     2/3 ★      director, genre           Gangs of New York
# 7     2/3 ★      director, genre           The Departed
# 8     1/3 ★      director                  The Last Temptation of Christ
# 9     1/3 ★      director                  Raging Bull
# 10    1/3 ★      director                  Bringing Out the Dead
#
# ================================================================================
# Query #6: 'batman dark knight'
# Criteria: {'title': 'Batman'}
# ================================================================================
# Precision@10: 60.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 0.60/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     1/3 ★      title                     Batman: The Dark Knight Returns, Part 2
# 2     0/3 ★      none                      The Dark Knight
# 3     0/3 ★      none                      The Dark Knight Rises
# 4     1/3 ★      title                     Batman
# 5     1/3 ★      title                     Batman
# 6     0/3 ★      none                      First Knight
# 7     0/3 ★      none                      Alone in the Dark
# 8     1/3 ★      title                     Batman Begins
# 9     1/3 ★      title                     Batman Forever
# 10    1/3 ★      title                     Batman & Robin
#
# ================================================================================
# Query #7: 'pixar animation'
# Criteria: {'genre': 'Animation'}
# ================================================================================
# Precision@10: 100.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 1.00/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     1/3 ★      genre                     Lilo & Stitch
# 2     1/3 ★      genre                     South Park: Bigger, Longer & Uncut
# 3     1/3 ★      genre                     Tangled
# 4     1/3 ★      genre                     Home on the Range
# 5     1/3 ★      genre                     Kung Fu Panda 2
# 6     1/3 ★      genre                     A Turtle's Tale: Sammy's Adventures
# 7     1/3 ★      genre                     Persepolis
# 8     1/3 ★      genre                     Finding Nemo
# 9     1/3 ★      genre                     Monsters University
# 10    1/3 ★      genre                     Dinosaur
#
# ================================================================================
# Query #8: 'tarantino 1994'
# Criteria: {'director': 'Tarantino', 'year': 1994}
# ================================================================================
# Precision@10: 100.0% | MRR: 1.000 | NDCG: 1.000 | Avg Relevance: 1.10/3.0
#
# Top 10 Results:
# Rank  Relevance  Matches                   Title
# --------------------------------------------------------------------------------
# 1     2/3 ★      director, year            Pulp Fiction
# 2     1/3 ★      director                  Inglourious Basterds
# 3     1/3 ★      director                  Kill Bill: Vol. 2
# 4     1/3 ★      director                  Reservoir Dogs
# 5     1/3 ★      director                  Django Unchained
# 6     1/3 ★      director                  Kill Bill: Vol. 1
# 7     1/3 ★      director                  Jackie Brown
# 8     1/3 ★      director                  The Hateful Eight
# 9     1/3 ★      year                      Police Academy: Mission to Moscow
# 10    1/3 ★      year                      Four Weddings and a Funeral
#
# ================================================================================
# SEARCH ENGINE EVALUATION - DETAILED RESULTS
# ================================================================================
#
# --------------------------------------------------------------------------------
#                                 OVERALL METRICS
# --------------------------------------------------------------------------------
# Average Precision@10: 95.00%
# Mean Reciprocal Rank: 0.8750
# Average NDCG:         1.0000
# Average Relevance:    1.36/3.0
#
# Total Queries Evaluated: 8
#
# Overall Rating: EXCELLENT ★★★★★
# ================================================================================
