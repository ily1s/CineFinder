# %%
import pandas as pd
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
nlp = spacy.load("en_core_web_sm")

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_movies.csv")

# %%
def preprocess_spacy(text):
    if not isinstance(text, str):
        return ""
    doc = nlp(text.lower())
    tokens = [
        tok.lemma_
        for tok in doc
        if not tok.is_stop and not tok.is_punct and tok.is_alpha
    ]
    return " ".join(tokens)

# %% [markdown]
# Prepare the dataset

# %%
df["Title_clean"] = df["Title"].apply(preprocess_spacy)
df["Overview_clean"] = df["Overview"].apply(preprocess_spacy)
df["Genres_clean"] = df["Genres"].apply(preprocess_spacy)
df["Director_clean"] = df["Director"].apply(preprocess_spacy)

# %%
df["combined"] = (
    df["Title_clean"] + " " +
    df["Overview_clean"] + " " +
    df["Genres_clean"] + " " +
    df["Director_clean"]
)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df["combined"])

# %%
def search_movie(query, top_n=10):
    query_clean = preprocess_spacy(query)
    query_vec = vectorizer.transform([query_clean])

    scores = cosine_similarity(query_vec, tfidf_matrix).flatten()
    top_idx = scores.argsort()[::-1][:top_n]

    results = df.iloc[top_idx].copy()
    results["score"] = scores[top_idx]
    return results[["Title", "Overview", "Genres", "Director", "score"]]

# %%
search_movie("action movie with a policeman", 10)
# Out:
#                                     Title  \
# 2222                       Disaster Movie
# 1711                           Grindhouse
# 2233                        Osmosis Jones
# 4574         My Big Fat Independent Movie
# 2936                                 Narc
# 1724                          The Wailing
# 3675                        Extreme Movie
# 3382                         Silent Movie
# 2044                               Wasabi
# 3907  Tim and Eric's Billion Dollar Movie
#
#                                                Overview  \
# 2222  The filmmaking team behind the hits "Scary Mov...
# 1711  Two full-length feature horror movies written ...
# 2233  A white blood cell policeman, with the help of...
# 4574  This film is a spoof along the lines of "Scary...
# 2936  When the trail goes cold on a murder investiga...
# 1724  A stranger arrives in a little village and soo...
# 3675  A sketch comedy movie about the joys and embar...
# 3382  Aspiring filmmakers Mel Funn, Marty Eggs and D...
# 2044  Hubert is a French policeman with very sharp m...
# 3907  Two guys get a billion dollars to make a movie...
#
#                                             Genres            Director  \
# 2222                       Comedy, Science Fiction     Jason Friedberg
# 1711                      Thriller, Action, Horror    Robert Rodriguez
# 2233  Adventure, Animation, Action, Comedy, Family      Bobby Farrelly
# 4574                                        Comedy  Philip Zlotorynski
# 2936               Crime, Drama, Thriller, Mystery        Joe Carnahan
# 1724                               Horror, Mystery         Na Hong-jin
# 3675                                        Comedy    Adam Jay Epstein
# 3382                                        Comedy          Mel Brooks
# 2044                         Drama, Action, Comedy     Gérard Krawczyk
# 3907                                        Comedy       Tim Heidecker
#
#          score
# 2222  0.309964
# 1711  0.246036
# 2233  0.233890
# 4574  0.218793
# 2936  0.216102
# 1724  0.187767
# 3675  0.174492
# 3382  0.174097
# 2044  0.172561
# 3907  0.168253

# %%
search("tarantino action", top_n=10)
# Out:
#                             Title  \
# 4406              Excessive Force
# 3029     Showdown in Little Tokyo
# 4706                 Diamond Ruff
# 3546               Pound of Flesh
# 4027                   Men of War
# 3416              Invasion U.S.A.
# 3430                The Corruptor
# 2131  The Man with the Iron Fists
# 3533                    Alatriste
# 2603                   The Marine
#
#                                                Overview  Genres  \
# 4406  Chicago policeman Terry McCain is determined t...  Action
# 3029  An American with a Japanese upbringing, Chris ...  Action
# 4706  Action - Orphan, con artist, crime boss and mi...  Action
# 3546  In China to donate his kidney to his dying nie...  Action
# 4027  Nick Gunar is a burnt-out, jaded and hard-up f...  Action
# 3416  A one-man army comes to the rescue of the Unit...  Action
# 3430  Danny is a young cop partnered with Nick, a se...  Action
# 2131  In feudal China, a blacksmith who makes weapon...  Action
# 3533  In 17th century Spain Diego Alatriste, a brave...  Action
# 2603  A group of diamond thieves on the run kidnap t...  Action
#
#                 Director  score
# 4406            Jon Hess   0.25
# 3029      Mark L. Lester   0.25
# 4706             Unknown   0.25
# 3546     Ernie Barbarash   0.25
# 4027          Perry Lang   0.25
# 3416         Joseph Zito   0.25
# 3430         James Foley   0.25
# 2131                 RZA   0.25
# 3533  Agustín Díaz Yanes   0.25
# 2603         John Bonito   0.25
